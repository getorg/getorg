# %%
from github import Github
import getorg
import ghlogin

# %%
gh = Github(login_or_token=ghlogin.gh_key)

# %%
org_locations, org_location_metadata = getorg.get_org_contributor_locations(gh, "usds")
# Out:
# ...............................

# %%
org_map = getorg.create_map_obj()

# %%
getorg.map_location_dict(org_map,org_locations)
